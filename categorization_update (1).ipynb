# %%
import pandas as pd

# %%
"""
video ID	an 11-digit string, which is unique
uploader	a string of the video uploader's username
age	an integer number of days between the date when the video was uploaded and Feb.15, 2007 (YouTube's establishment)
category	a string of the video category chosen by the uploader
length	an integer number of the video length
views	an integer number of the views
rate	a float number of the video rate
ratings	an integer number of the ratings
comments	an integer number of the comments
related IDs	up to 20 strings of the related video IDs"""
# Out:
# "\nvideo ID\tan 11-digit string, which is unique\nuploader\ta string of the video uploader's username\nage\tan integer number of days between the date when the video was uploaded and Feb.15, 2007 (YouTube's establishment)\ncategory\ta string of the video category chosen by the uploader\nlength\tan integer number of the video length\nviews\tan integer number of the views\nrate\ta float number of the video rate\nratings\tan integer number of the ratings\ncomments\tan integer number of the comments\nrelated IDs\tup to 20 strings of the related video IDs"

# %%
root_path = "C:\\Users\\Ritik's PC\\Desktop\\College 4th Year\\Spring 2022\\CS 436\\youtube-network-aggregation\\YouTubeData\\080327\\"
column_names = ["video_id", "uploader", "age", 'category', "length", "views", "rate", "ratings", "comments",
            "r1", "r2", "r3", "r4", "r5", "r6", "r7", "r8", "r9", "r10", "r11", "r12", "r13", "r14", "r15", "r16", "r17", "r18", "r19", "r20"  
           ]
df0 = pd.read_csv(root_path+"0.txt", sep="\t", names=column_names, header=None)
df1 = pd.read_csv(root_path+"1.txt", sep="\t", names=column_names, header=None)
df2 = pd.read_csv(root_path+"2.txt", sep="\t", names=column_names, header=None)
df3 = pd.read_csv(root_path+"3.txt", sep="\t", names=column_names, header=None)

# %%
df =pd.concat([df0, df1, df2, df3])

# %%
df
# Out:
#            video_id           uploader     age         category  length  \
# 0       gFa1YMEJFag            sxephil  1135.0    Entertainment   270.0
# 1       pSJ4hv28zaI  thecomputernerd01  1136.0           Comedy   216.0
# 2       uHVEDq6RVXc    barelypolitical  1134.0  News & Politics    56.0
# 3       K7Om0QZy-38          SouljaBoy  1134.0            Music   185.0
# 4       DCAO6bZa31o    AssociatedPress  1134.0  News & Politics    45.0
# ...             ...                ...     ...              ...     ...
# 269220  _BNIAMe2_qY            ATi0021   934.0    Entertainment    31.0
# 269221  Vm6g-1BrA3g        AdriaanGTAP   865.0    Entertainment    58.0
# 269222  2nBgXVpfQ5Y         WolfMan316   482.0    Entertainment   155.0
# 269223  -U1fJzPGxKw         bejerano9o   956.0    Entertainment    53.0
# 269224  eo7IPe_gh1Y        GTAmissions   730.0    Entertainment   402.0
#
#            views  rate  ratings  comments           r1  ...          r11  \
# ...

# %%
#bar graph shows videos in each category

df.groupby('category')['video_id'].count().plot(kind="bar", color="purple")

# %%
#pie plot shows videos in each category

df.groupby('category')['video_id'].count().plot(kind="pie", figsize=(15, 10))

# %%
# bar chart by category
# find top ten users wtih maximum uploads
# top ten videos by viewes /
# top ten videos by views/length/ratings/comments in every category

# %%
# top 10 users with maximum number of uploads
counts_df = df.groupby('uploader').size().reset_index(name="counts").sort_values(by=["counts"], ascending=False)[:10]
counts_df.plot(x="uploader", y="counts", kind="barh", color="red")

# uploader_counts.sort_values(by=["counts"], ascending = False)[:10].plot(kind="bar")

# %%
# top 10 users with maximum number of uploads

explode = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)
colors = ['pink', 'silver', 'steelblue', 'orange', 'green', 'yellow', 'darkred', 'purple', 'lightgreen', 'darkblue']
counts_df = df.groupby('uploader').size().reset_index(name="counts").sort_values(by=["counts"], ascending=False)[:10]
counts_df.plot(x="uploader", y="counts", kind="pie", figsize=(15, 12),  explode=explode, autopct='%1.0f%%', startangle=60, colors=colors)

# uploader_counts.sort_values(by=["counts"], ascending = False)[:10].plot(kind="bar")

# %%
colors = 'green'
df.groupby('category').agg({'views':[ 'mean',]}).plot(kind='barh', color=colors)

# %%
df.groupby('category').agg({'length':['min', 'max', 'mean'], 'rate':['mean', ], 'ratings':['min', 'max'] })
# Out:
#                       length                             rate ratings  \
#                          min        max        mean      mean     min
# category
#  UNA                     1.0     3714.0  157.354732  3.957384     0.0
# Autos & Vehicles         0.0     1731.0  153.550414  3.768118     0.0
# Comedy                   0.0     5719.0  163.376315  3.884254     0.0
# Education                0.0     5376.0  280.198707  3.477647     0.0
# Entertainment            0.0  1623135.0  256.385200  4.023313     0.0
# Film & Animation         0.0     5687.0  223.568315  4.287451     0.0
# Howto & Style            0.0     6092.0  241.978536  3.667508     0.0
# Music                    1.0    17667.0  237.694869  4.423009     0.0
# News & Politics          1.0     6950.0  261.998322  3.970567     0.0
# Nonprofits & Activism    1.0     3769.0  242.819139  3.830306     0.0
# People & Blogs           0.0    12726.0  208.391868  3.775700     0.0
# ...

# %%
df.groupby('category').agg({'length':[ 'mean'] }).plot(kind='barh', color="green")

# %%
df.groupby('category').agg({'ratings':[ 'mean'] }).plot(kind='barh', color="pink")

# %%
df.groupby('category').agg({'rate':[ 'mean'] }).plot(kind='pie', y="rate",figsize=(10, 18), autopct='%1.0f%%')
df.groupby('category').agg({'rate':[ 'mean'] }).plot(kind='barh', color="orange")
#df.groupby('category')['video_id'].count().plot(kind="pie", figsize=(15, 10))

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(nrows=2, ncols=1)

df.groupby('category').agg({'ratings':[ 'mean'] }).plot(y="ratings",kind='pie', ax=axes[0], figsize=(15, 30))
df.groupby('category').agg({'rate':[ 'mean'] }).plot(kind='barh', ax=axes[1])
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001B093D45BE0>,
# ...
#       dtype=object)

# %%
#df.groupby('category').agg({'age':[ 'mean'] }).plot(kind='barh')
df['age_yrs']=df.age.map(lambda x: x//365)
df.groupby('category').agg({'age_yrs':[ 'mean'] }).plot(kind='barh')

# %%
#df.groupby('category').agg({'age':[ 'mean'] }).plot(kind='barh')
df['age_yrs']=df.age.map(lambda x: x//365)
df.groupby('category').agg({'age_yrs':[ 'mean'] }).plot(kind='hist', color="magenta")

# %%
#df.groupby('age_yrs').plot(kind='barh')
df.groupby('age_yrs').agg({'views':[ 'count',]}).plot(kind='barh')

# %%
df.groupby('age_yrs').agg({'length':[ 'sum',]}).plot(kind='barh')

# %%
df.groupby('category').agg({'length':['sum',]}).plot(kind='barh')

# %%
df.groupby('category').agg({'length':['min', 'mean'], 'rate':['mean', ], 'ratings':['min', 'max'] })
# Out:
#                       length                  rate ratings
#                          min        mean      mean     min       max
# category
#  UNA                     1.0  157.354732  3.957384     0.0   47863.0
# Autos & Vehicles         0.0  153.550414  3.768118     0.0    9550.0
# Comedy                   0.0  163.376315  3.884254     0.0  287260.0
# Education                0.0  280.198707  3.477647     0.0    6996.0
# Entertainment            0.0  256.385200  4.023313     0.0  168642.0
# Film & Animation         0.0  223.568315  4.287451     0.0   88794.0
# Howto & Style            0.0  241.978536  3.667508     0.0   48094.0
# Music                    1.0  237.694869  4.423009     0.0  329108.0
# News & Politics          1.0  261.998322  3.970567     0.0   33330.0
# Nonprofits & Activism    1.0  242.819139  3.830306     0.0    6604.0
# People & Blogs           0.0  208.391868  3.775700     0.0   79275.0
# Pets & Animals           0.0  128.996815  3.918513     0.0   58850.0
# ...

# %%
buckets = [0,100,1000,10000, 100000, 1000000]
labels = ['<100', '<1000', '<10000', "<100000", "<1000000"]
series = pd.cut(df['views'], buckets, labels=labels)
views_df = series.to_frame()
views_df.groupby('views').size().plot(kind="barh")

# %%
explode = (0.05, 0.05, 0.05, 0.05, 0.05)
colors = ['pink', 'silver', 'steelblue', 'darkorange', 'green']
buckets = [0,100,1000,10000, 100000, 1000000]
labels = ['<100', '<1000', '<10000', "<100000", "<1000000"]
series = pd.cut(df['views'], buckets, labels=labels)
views_df = series.to_frame()
views_df.groupby('views').size().plot(kind="pie",figsize=(10, 18), autopct='%1.0f%%',  explode=explode, startangle=60, colors=colors)

# %%
df.plot.scatter(x='views', y='comments')

# %%
df[df.comments>200000]
# Out:
#            video_id         uploader    age         category  length  \
# 1053    kHmvkRoEowc  itschriscrocker  937.0    Entertainment   131.0
# 32719   uSVRuA8RpkU     duelistXmist  784.0    Entertainment    30.0
# 231422  -oHivXjiX_w   makedoniatruth  697.0  News & Politics   144.0
#
#              views  rate   ratings  comments           r1  ...          r12  \
# 1053    18235463.0  2.42  122129.0  259683.0  h863nXDqCM0  ...  uEE3akeFeQU
# 32719    1159719.0  0.00       0.0  240970.0  rOscf5MqRNg  ...  XctRQksfAE8
# 231422    936892.0  3.84    3058.0  210672.0  CAYIDO5832Q  ...  BVOfzCCL6HQ
#
#                 r13          r14          r15          r16          r17  \
# 1053    aiqkDm9UoKo  Yd1Oe1LELcc          NaN          NaN          NaN
# 32719   e-tA2yO-YEI  xTkLDGtu36Q  LwAy1svqVes  t2Xn9wVsvvE  0-oLJZ7mifM
# 231422  nTZoDdH8fG0  bq12AUsQvIk  1q4-QeRBuy4  S2yY3s8UaB0  HDlEX-mIp6Q
#
#                 r18          r19          r20 age_yrs
# ...

# %%
df[df.comments <=50000].plot.scatter(x='views', y='comments')

# %%
df.plot.scatter(x='age', y='comments')
